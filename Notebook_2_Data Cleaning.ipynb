# %% [markdown]
# The project's primary objective is to create a Restaurant Recommender Application designed to assist users in locating dining establishments that align with their tastes. Through the implementation of machine learning techniques, I have gathered genuine restaurant reviews and established a sophisticated recommender system.
#
# In my project, I conducted an in-depth analysis of restaurant reviews from Vancouver. Throughout the project, I gathered data from web sources, constructed a comprehensive data frame, established a robust recommender system, and developed a user-friendly application to utilize the recommendation system seamlessly.

# %% [markdown]
# __Please note: this is notebook 2 of 3.__
#
# In this notebook I combined reviews, rating and restaurant info data in one dataframe. I conducted data cleaning and exploratory data analysis (EDA) to prepare the data for subsequent analysis and modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# CoreFoundation              NA
# Foundation                  NA
# PyObjCTools                 NA
# anyio                       NA
# appnope                     0.1.2
# arrow                       1.2.3
# asttokens                   NA
# attr                        22.1.0
# babel                       2.11.0
# backcall                    0.2.0
# brotli                      NA
# certifi                     2023.05.07
# chardet                     4.0.0
# charset_normalizer          2.0.4
# colorama                    0.4.6
# comm                        0.1.2
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# executing                   0.8.3
# fastjsonschema              NA
# fqdn                        NA
# idna                        3.4
# importlib_metadata          NA
# importlib_resources         NA
# ipykernel                   6.19.2
# ipython_genutils            0.2.0
# isoduration                 NA
# jedi                        0.18.1
# jinja2                      3.1.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.17.3
# jupyter_events              0.6.3
# jupyter_server              2.5.0
# jupyterlab_server           2.22.0
# markupsafe                  2.1.1
# mpl_toolkits                NA
# nbformat                    5.7.0
# numpy                       1.24.3
# objc                        9.0
# packaging                   23.0
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                2.5.2
# prometheus_client           NA
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pvectorc                    NA
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pyrsistent                  NA
# pythonjsonlogger            NA
# requests                    2.29.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# send2trash                  NA
# setuptools                  67.8.0
# six                         1.16.0
# sniffio                     1.2.0
# socks                       1.7.1
# sphinxcontrib               NA
# stack_data                  0.2.0
# tornado                     6.2
# traitlets                   5.7.1
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.16
# wcwidth                     0.2.5
# webcolors                   1.13
# websocket                   0.58.0
# yaml                        6.0
# zipp                        NA
# zmq                         25.1.0
# zope                        NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.0
# jupyter_client      8.1.0
# jupyter_core        5.3.0
# jupyterlab          3.6.3
# notebook            6.5.4
# -----
# Python 3.8.16 (default, Mar  1 2023, 21:19:10) [Clang 14.0.6 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2023-11-02 16:24
# </pre>
# </details>

# %% [markdown]
# ### Review

# %% [markdown]
# I'll begin by downloading the CSV file containing the scraped reviews and then proceed with the data cleaning process.

# %%
df_review = pd.read_csv('/Users/evgenijkucukov/Desktop/Brainstation/Portfolio/Restaurant_reviews_project/df_review_1')
df_review
# Out:
#                           restaurant  \
# 0                   Freshslice Pizza
# 1                   Freshslice Pizza
# 2                   Freshslice Pizza
# 3                   Freshslice Pizza
# 4                   Freshslice Pizza
# ...                              ...
# 18635  1050. Beach Ave Bar and Grill
# 18636  1050. Beach Ave Bar and Grill
# 18637  1050. Beach Ave Bar and Grill
# 18638  1050. Beach Ave Bar and Grill
# 18639  1050. Beach Ave Bar and Grill
#
#                                                   review
# 0      Simar arora is very nice and sweet girl who se...
# 1      I went to the Granville and 2400 block Vancouv...
# 2      We were in a hurry to grab a snack. Pizza was ...
# 3      Freshslice Pizza is hands down one of the best...
# 4      I met there with their staff girl named Kiran,...
# ...                                                  ...
# 18635  Stopped in for lunch while I was walking the S...
# 18636  Great food and beer in a perfect spot looking ...
# 18637  We dine here often. And I almost always get a ...
# 18638  The Beach Ave bar and grill is lovely spot to ...
# 18639  My wife & I, who live in northern BC, rented a...
#
# [18640 rows x 2 columns]

# %%
# Check how many values are missing
df_review.isna().sum()
# Out:
# restaurant    0
# review        0
# dtype: int64

# %% [markdown]
# There are not missing values.

# %% [markdown]
# It's possible to observe that some restaurant names lack associated rating numbers. Additionally, we've identified duplicated restaurants resulting from web page advertisements. To address this, we should proceed to remove these particular restaurants from the dataset.

# %%
# delete ads reataurants (wo rate numbers)
df_review = df_review[df_review['restaurant'].str.contains(r'\d')]

# %% [markdown]
# After completing the data cleaning process, my next step is to merge all the dataframes based on the restaurant name as the common identifier. To ensure a smooth merging process, I plan to omit the rating numbers, as they may introduce inconsistencies during the merge.

# %%
df_review['restaurant'] = df_review['restaurant'].str.replace(r'^\d+\. ', '',regex=True)
df_review
# Out:
# /var/folders/0z/fdtwx1zs7lg98s4zb6q_8_4h0000gn/T/ipykernel_4151/2616152244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review['restaurant'] = df_review['restaurant'].str.replace(r'^\d+\. ', '',regex=True)
#                            restaurant  \
# 26     Hydra Estiatorio Mediterranean
# 27     Hydra Estiatorio Mediterranean
# 28     Hydra Estiatorio Mediterranean
# 29     Hydra Estiatorio Mediterranean
# 30     Hydra Estiatorio Mediterranean
# ...                               ...
# 18635         Beach Ave Bar and Grill
# 18636         Beach Ave Bar and Grill
# 18637         Beach Ave Bar and Grill
# 18638         Beach Ave Bar and Grill
# 18639         Beach Ave Bar and Grill
#
#                                                   review
# 26     Wonderful fresh exotic Greek food that is deli...
# 27     Food was delicious, packed full of flavors. Th...
# 28     Hello, We would like to say thank you for the ...
# 29     Happy hour was amazing. Buck a shuck oysters a...
# 30     Roman was the best waiter! he checked up on us...
# ...                                                  ...
# 18635  Stopped in for lunch while I was walking the S...
# 18636  Great food and beer in a perfect spot looking ...
# 18637  We dine here often. And I almost always get a ...
# 18638  The Beach Ave bar and grill is lovely spot to ...
# 18639  My wife & I, who live in northern BC, rented a...
#
# [16715 rows x 2 columns]

# %%
# let's check duplicates
duplicates = df_review[df_review.duplicated()]
duplicates
# Out:
#                  restaurant                                             review
# 128      Seaside Provisions  Thank you so much for the wonderful review! It...
# 185      Atlas Steak + Fish                      Thank you for the kind words!
# 307    Freebird Table & Bar  Thank you kindly for taking the time to write ...
# 317    Freebird Table & Bar  Thank you for the wonderful review! It was a p...
# 932     Seasons in the Park  Thank you for taking the time to provide us wi...
# ...                     ...                                                ...
# 18430      Freshslice Pizza  Thanks for taking the time to leave us a revie...
# 18440      Freshslice Pizza  We're thrilled to hear that you had a great ex...
# 18442      Freshslice Pizza  We're thrilled to hear that you had a great ex...
# 18444      Freshslice Pizza  We're thrilled to hear that you had a great ex...
# 18611          Boston Pizza  Thanks for the 5-star review! We're glad to he...
#
# [104 rows x 2 columns]

# %%
# let's remove duplicated raws
df_review = df_review.drop_duplicates()

# %%
# sanity check
duplicates_1 = df_review[df_review.duplicated()]
duplicates_1
# Out:
# Empty DataFrame
# Columns: [restaurant, review]
# Index: []

# %% [markdown]
# There ara not duplicated values.

# %%
# let's check unique values
df_review.nunique()
# Out:
# restaurant     1009
# review        16606
# dtype: int64

# %% [markdown]
# In the cleaned dataframe, we have a total of 1,009 restaurants and 16,606 reviews.

# %% [markdown]
# Now let's repeat the same steps with rating and restaurant info data.

# %% [markdown]
# ### Rating

# %%
df_rating = pd.read_csv('/Users/evgenijkucukov/Desktop/Brainstation/Portfolio/Restaurant_reviews_project/df_rating_1')
df_rating
# Out:
#                              restaurant  rating
# 0            Kozak Ukrainian Restaurant     4.5
# 1     1. Hydra Estiatorio Mediterranean     5.0
# 2                       2. Black + Blue     4.5
# 3                    3. Alouette Bistro     5.0
# 4                 4. Seaside Provisions     5.0
# ...                                 ...     ...
# 1220                 1046. Boston Pizza     3.5
# 1221            1047. Mirchi Restaurant     4.0
# 1222      1048. Beach Ave Bar and Grill     5.0
# 1223                   1049. Say Mercy!     4.5
# 1224                  1050. Tokyo Joe's     4.0
#
# [1225 rows x 2 columns]

# %%
# delete ads reataurants (wo rate numbers)
df_rating = df_rating[df_rating['restaurant'].str.contains(r'\d')]
df_rating
# Out:
#                              restaurant  rating
# 1     1. Hydra Estiatorio Mediterranean     5.0
# 2                       2. Black + Blue     4.5
# 3                    3. Alouette Bistro     5.0
# 4                 4. Seaside Provisions     5.0
# 5           5. Salmon n' Bannock Bistro     4.5
# ...                                 ...     ...
# 1220                 1046. Boston Pizza     3.5
# 1221            1047. Mirchi Restaurant     4.0
# 1222      1048. Beach Ave Bar and Grill     5.0
# 1223                   1049. Say Mercy!     4.5
# 1224                  1050. Tokyo Joe's     4.0
#
# [1050 rows x 2 columns]

# %% [markdown]
# Delete rating numbers for the all restaurants.

# %%
df_rating['restaurant'] = df_rating['restaurant'].str.replace(r'^\d+\. ', '',regex=True)
# Out:
# /var/folders/0z/fdtwx1zs7lg98s4zb6q_8_4h0000gn/T/ipykernel_4151/3924685758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rating['restaurant'] = df_rating['restaurant'].str.replace(r'^\d+\. ', '',regex=True)

# %% [markdown]
# ### Merge

# %% [markdown]
# We will merge two clean dataframes based on the restaurant name.

# %%
df = df_review.merge(df_rating, on='restaurant', how='left' )
df
# Out:
#                            restaurant  \
# 0      Hydra Estiatorio Mediterranean
# 1      Hydra Estiatorio Mediterranean
# 2      Hydra Estiatorio Mediterranean
# 3      Hydra Estiatorio Mediterranean
# 4      Hydra Estiatorio Mediterranean
# ...                               ...
# 18442         Beach Ave Bar and Grill
# 18443         Beach Ave Bar and Grill
# 18444         Beach Ave Bar and Grill
# 18445         Beach Ave Bar and Grill
# 18446         Beach Ave Bar and Grill
#
#                                                   review  rating
# 0      Wonderful fresh exotic Greek food that is deli...     5.0
# 1      Food was delicious, packed full of flavors. Th...     5.0
# 2      Hello, We would like to say thank you for the ...     5.0
# 3      Happy hour was amazing. Buck a shuck oysters a...     5.0
# 4      Roman was the best waiter! he checked up on us...     5.0
# ...                                                  ...     ...
# 18442  Stopped in for lunch while I was walking the S...     5.0
# 18443  Great food and beer in a perfect spot looking ...     5.0
# 18444  We dine here often. And I almost always get a ...     5.0
# 18445  The Beach Ave bar and grill is lovely spot to ...     5.0
# 18446  My wife & I, who live in northern BC, rented a...     5.0
#
# [18447 rows x 3 columns]

# %%
# check unique values
df.nunique()
# Out:
# restaurant     1009
# review        16606
# rating            4
# dtype: int64

# %%
# check NaN values
df.isna().sum()
# Out:
# restaurant     0
# review         0
# rating        45
# dtype: int64

# %% [markdown]
# Let's determine the number of restaurants that do not have a rating.

# %%
missing_rating_df = df.loc[df['rating'].isna()]
missing_rating_df['restaurant'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 15586    Ki-Isu Japanese Restaurant
# 15587    Ki-Isu Japanese Restaurant
# 15588    Ki-Isu Japanese Restaurant
# 15589    Ki-Isu Japanese Restaurant
# 15590    Ki-Isu Japanese Restaurant
# 15591    Ki-Isu Japanese Restaurant
# 15592    Ki-Isu Japanese Restaurant
# 15593    Ki-Isu Japanese Restaurant
# 15594    Ki-Isu Japanese Restaurant
# 15595    Ki-Isu Japanese Restaurant
# 15596    Ki-Isu Japanese Restaurant
# 15597    Ki-Isu Japanese Restaurant
# 15598    Ki-Isu Japanese Restaurant
# 15599    Ki-Isu Japanese Restaurant
# 15600    Ki-Isu Japanese Restaurant
# 15944     Won More Szechuan Cuisine
# 15945     Won More Szechuan Cuisine
# 15946     Won More Szechuan Cuisine
# 15947     Won More Szechuan Cuisine
# 15948     Won More Szechuan Cuisine
# 15949     Won More Szechuan Cuisine
# 15950     Won More Szechuan Cuisine
# 15951     Won More Szechuan Cuisine
# 15952     Won More Szechuan Cuisine
# 15953     Won More Szechuan Cuisine
# 15954     Won More Szechuan Cuisine
# 15955     Won More Szechuan Cuisine
# 15956     Won More Szechuan Cuisine
# 15957     Won More Szechuan Cuisine
# 15958     Won More Szechuan Cuisine
# 18091               Johnny’s On Oak
# 18092               Johnny’s On Oak
# 18093               Johnny’s On Oak
# 18094               Johnny’s On Oak
# 18095               Johnny’s On Oak
# 18096               Johnny’s On Oak
# 18097               Johnny’s On Oak
# 18098               Johnny’s On Oak
# 18099               Johnny’s On Oak
# 18100               Johnny’s On Oak
# 18101               Johnny’s On Oak
# 18102               Johnny’s On Oak
# 18103               Johnny’s On Oak
# 18104               Johnny’s On Oak
# 18105               Johnny’s On Oak
# Name: restaurant, dtype: object>

# %% [markdown]
# Let's find the ratings of 3 restaurants and fill them manually.

# %%
# fill missing rating for 45 restaurants

restaurant_rating_map = {
    'Ki-Isu Japanese Restaurant': 4.5,
    'Won More Szechuan Cuisine': 4,
    'Johnny’s On Oak': 3.5,}

df['rating'] = df['rating'].fillna(df['restaurant'].map(restaurant_rating_map))

# %%
# sanity check
df.isna().sum()
# Out:
# restaurant    0
# review        0
# rating        0
# dtype: int64

# %% [markdown]
# There are not NaN values.

# %% [markdown]
# ### Restaurant info

# %%
df_info = pd.read_csv('/Users/evgenijkucukov/Desktop/Brainstation/Portfolio/Restaurant_reviews_project/df_type')
df_info
# Out:
#               restaurant           type
# 0       Freshslice Pizza        €2 - €5
# 1       Freshslice Pizza          Pizza
# 2       Freshslice Pizza  Lunch, Dinner
# 3     3. Alouette Bistro       €8 - €34
# 4     3. Alouette Bistro         French
# ...                  ...            ...
# 3124   1050. Tokyo Joe's  Lunch, Dinner
# 3125   1050. Tokyo Joe's        Takeout
# 3126    Freshslice Pizza        €2 - €5
# 3127    Freshslice Pizza          Pizza
# 3128    Freshslice Pizza  Lunch, Dinner
#
# [3129 rows x 2 columns]

# %% [markdown]
# Let's repeat the same cleaning steps which we completed with reviews and rating.

# %%
# delete ads reataurants (wo rate numbers)
df_info = df_info[df_info['restaurant'].str.contains(r'\d')]
df_info
# Out:
#                          restaurant                                      type
# 3                3. Alouette Bistro                                  €8 - €34
# 4                3. Alouette Bistro                                    French
# 5                3. Alouette Bistro  Breakfast, Lunch, Dinner, Brunch, Drinks
# 6             4. Seaside Provisions                                  €8 - €41
# 7             4. Seaside Provisions                      Seafood, Dining bars
# ...                             ...                                       ...
# 3121  1049. Beach Ave Bar and Grill           Brew Pub, Pub, Beer restaurants
# 3122  1049. Beach Ave Bar and Grill             Lunch, Dinner, Brunch, Drinks
# 3123              1050. Tokyo Joe's                    Japanese, Sushi, Asian
# 3124              1050. Tokyo Joe's                             Lunch, Dinner
# 3125              1050. Tokyo Joe's                                   Takeout
#
# [2577 rows x 2 columns]

# %% [markdown]
# Delete rating numbers for all restaurants.

# %%
df_info['restaurant'] = df_info['restaurant'].str.replace(r'^\d+\. ', '',regex=True)
df_info
# Out:
# /var/folders/0z/fdtwx1zs7lg98s4zb6q_8_4h0000gn/T/ipykernel_4151/4117296768.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_info['restaurant'] = df_info['restaurant'].str.replace(r'^\d+\. ', '',regex=True)
#                    restaurant                                      type
# 3             Alouette Bistro                                  €8 - €34
# 4             Alouette Bistro                                    French
# 5             Alouette Bistro  Breakfast, Lunch, Dinner, Brunch, Drinks
# 6          Seaside Provisions                                  €8 - €41
# 7          Seaside Provisions                      Seafood, Dining bars
# ...                       ...                                       ...
# 3121  Beach Ave Bar and Grill           Brew Pub, Pub, Beer restaurants
# 3122  Beach Ave Bar and Grill             Lunch, Dinner, Brunch, Drinks
# 3123              Tokyo Joe's                    Japanese, Sushi, Asian
# 3124              Tokyo Joe's                             Lunch, Dinner
# 3125              Tokyo Joe's                                   Takeout
#
# [2577 rows x 2 columns]

# %% [markdown]
# As observed, we have three rows of data for each restaurant, each containing different types of information. Let's consolidate all this information into a single row, separated by commas.

# %%
df_info_1 = df_info.groupby('restaurant')['type'].apply(','.join).reset_index()
df_info_1

# %% [markdown]
# Now, let's split each restaurant's characteristics, which are currently separated by commas, into separate columns.

# %%
# Find the maximum number of elements in any string
max_elements = df_info_1['type'].str.count(',') + 1
max_columns = max_elements.max()

# Split the 'type' column into a list of elements
df_info_1['elements'] = df_info_1['type'].str.split(',')

# Expand the list of elements into separate columns
for i in range(max_columns):
    df_info_1[f'col{i+1}'] = df_info_1['elements'].apply(lambda x: x[i] if i < len(x) else None)

# Drop the unnecessary columns
df_info_1.drop(columns=['type', 'elements'], inplace=True)

df_info_1
# Out:
#                                       restaurant       col1  \
# 0    1927 Lobby Lounge at Rosewood Hotel Georgia  €26 - €34
# 1                            1931 Gallery Bistro  €14 - €24
# 2                    4 Stones Vegetarian Cuisine    Chinese
# 3                             A La Mode Pie Café      Soups
# 4                    A Taste Of India Restaurant     Indian
# ..                                           ...        ...
# 892         iDen & Quan Ju De Beijing Duck House    Chinese
# 893                             sushi California   Japanese
# 894                                  tetsu Sushi   Japanese
# 895                                    the apron   €3 - €21
# 896                                   the change   €7 - €34
#
#                     col2            col3                 col4  \
# 0                    Bar        Canadian             Wine Bar
# 1               Canadian    Contemporary                 None
# 2                  Asian       Taiwanese                 None
# 3                   Cafe        Canadian            Breakfast
# 4    Vegetarian Friendly   Vegan Options                Lunch
# ..                   ...             ...                  ...
# 892             European           Asian             Canadian
# 893                Sushi           Asian  Vegetarian Friendly
# 894                Sushi           Asian              Seafood
# 895             Canadian   International  Vegetarian Friendly
# 896              Chinese           Asian               Fusion
#
#                      col5               col6             col7  \
# 0                   Lunch             Dinner           Brunch
# 1                    None               None             None
# 2                    None               None             None
# 3                   Lunch             Dinner           Brunch
# 4                  Dinner         Late Night             None
# ..                    ...                ...              ...
# 892             Malaysian   Central European   South American
# 893   Gluten Free Options              Lunch           Dinner
# 894   Vegetarian Friendly             Dinner             None
# 895   Gluten Free Options               None             None
# 896                 Lunch             Dinner             None
#
#                   col8                    col9  ...           col29  \
# 0               Drinks                    None  ...            None
# 1                 None                    None  ...            None
# 2                 None                    None  ...            None
# 3              Takeout   Wheelchair Accessible  ...            None
# 4                 None                    None  ...            None
# ..                 ...                     ...  ...             ...
# 892   Central American         Beijing cuisine  ...   Table Service
# 893               None                    None  ...            None
# 894               None                    None  ...            None
# 895               None                    None  ...            None
# 896               None                    None  ...            None
#
#          col30                     col31         col32                  col33  \
# 0         None                      None          None                   None
# 1         None                      None          None                   None
# 2         None                      None          None                   None
# 3         None                      None          None                   None
# 4         None                      None          None                   None
# ..         ...                       ...           ...                    ...
# 892   Jazz Bar   Non-smoking restaurants   Sports bars   Gift Cards Available
# 893       None                      None          None                   None
# 894       None                      None          None                   None
# 895       None                      None          None                   None
# 896       None                      None          None                   None
#
#     col34 col35 col36 col37 col38
# 0    None  None  None  None  None
# 1    None  None  None  None  None
# 2    None  None  None  None  None
# 3    None  None  None  None  None
# 4    None  None  None  None  None
# ..    ...   ...   ...   ...   ...
# 892  None  None  None  None  None
# 893  None  None  None  None  None
# 894  None  None  None  None  None
# 895  None  None  None  None  None
# 896  None  None  None  None  None
#
# [897 rows x 39 columns]

# %%
# check which columns have more values
df_info_1.nunique()
# Out:
# restaurant    897
# col1          208
# col2          104
# col3           84
# col4           78
# col5           69
# col6           57
# col7           54
# col8           47
# col9           36
# col10          34
# col11          31
# col12          25
# col13          24
# col14          19
# col15          17
# col16          16
# col17          12
# col18          12
# col19          11
# col20           7
# col21           8
# col22           8
# col23           7
# col24           5
# col25           6
# col26           4
# col27           4
# col28           4
# col29           3
# col30           3
# col31           3
# col32           2
# col33           2
# col34           1
# col35           1
# col36           1
# col37           1
# col38           1
# dtype: int64

# %% [markdown]
# It's evident that columns 1 to 4 contain a substantial amount of relevant information about the restaurants. Therefore, let's proceed to remove the remaining columns.

# %%
# Drop columns
columns_to_drop = ['col38', 'col37', 'col36', 'col35', 'col34', 'col33', 'col32',
                   'col31', 'col30', 'col29', 'col28', 'col27', 'col26', 'col25',
                   'col24', 'col25', 'col24', 'col23', 'col22', 'col21', 'col20',
                   'col19', 'col18', 'col17', 'col16', 'col15', 'col14', 'col13', 
                   'col12', 'col11', 'col10', 'col9', 'col8', 'col7', 'col6',
                   'col5']
df_info_1.drop(columns=columns_to_drop, inplace=True)

df_info_1
# Out:
#                                       restaurant       col1  \
# 0    1927 Lobby Lounge at Rosewood Hotel Georgia  €26 - €34
# 1                            1931 Gallery Bistro  €14 - €24
# 2                    4 Stones Vegetarian Cuisine    Chinese
# 3                             A La Mode Pie Café      Soups
# 4                    A Taste Of India Restaurant     Indian
# ..                                           ...        ...
# 892         iDen & Quan Ju De Beijing Duck House    Chinese
# 893                             sushi California   Japanese
# 894                                  tetsu Sushi   Japanese
# 895                                    the apron   €3 - €21
# 896                                   the change   €7 - €34
#
#                     col2            col3                 col4
# 0                    Bar        Canadian             Wine Bar
# 1               Canadian    Contemporary                 None
# 2                  Asian       Taiwanese                 None
# 3                   Cafe        Canadian            Breakfast
# 4    Vegetarian Friendly   Vegan Options                Lunch
# ..                   ...             ...                  ...
# 892             European           Asian             Canadian
# 893                Sushi           Asian  Vegetarian Friendly
# 894                Sushi           Asian              Seafood
# 895             Canadian   International  Vegetarian Friendly
# 896              Chinese           Asian               Fusion
#
# [897 rows x 5 columns]

# %%
# combine restaurant' characteristics in one column 
df_info_1['Cuisine'] = df_info_1['col1'].str.cat([df_info_1['col2'], df_info_1['col3']], sep=', ')
df_info_1
# Out:
#                                       restaurant       col1  \
# 0    1927 Lobby Lounge at Rosewood Hotel Georgia  €26 - €34
# 1                            1931 Gallery Bistro  €14 - €24
# 2                    4 Stones Vegetarian Cuisine    Chinese
# 3                             A La Mode Pie Café      Soups
# 4                    A Taste Of India Restaurant     Indian
# ..                                           ...        ...
# 892         iDen & Quan Ju De Beijing Duck House    Chinese
# 893                             sushi California   Japanese
# 894                                  tetsu Sushi   Japanese
# 895                                    the apron   €3 - €21
# 896                                   the change   €7 - €34
#
#                     col2            col3                 col4  \
# 0                    Bar        Canadian             Wine Bar
# 1               Canadian    Contemporary                 None
# 2                  Asian       Taiwanese                 None
# 3                   Cafe        Canadian            Breakfast
# 4    Vegetarian Friendly   Vegan Options                Lunch
# ..                   ...             ...                  ...
# 892             European           Asian             Canadian
# 893                Sushi           Asian  Vegetarian Friendly
# 894                Sushi           Asian              Seafood
# 895             Canadian   International  Vegetarian Friendly
# 896              Chinese           Asian               Fusion
#
#                                          Cuisine
# 0                      €26 - €34, Bar,  Canadian
# 1             €14 - €24, Canadian,  Contemporary
# 2                    Chinese,  Asian,  Taiwanese
# 3                        Soups,  Cafe,  Canadian
# 4    Indian, Vegetarian Friendly,  Vegan Options
# ..                                           ...
# 892                   Chinese,  European,  Asian
# 893                     Japanese,  Sushi,  Asian
# 894                     Japanese,  Sushi,  Asian
# 895           €3 - €21, Canadian,  International
# 896                    €7 - €34, Chinese,  Asian
#
# [897 rows x 6 columns]

# %% [markdown]
# Let's delete col1, 2, 3, 4.

# %%
df_type = df_info_1.drop(columns = ['col1', 'col2', 'col3', 'col4'])

# %%
df_type
# Out:
#                                       restaurant  \
# 0    1927 Lobby Lounge at Rosewood Hotel Georgia
# 1                            1931 Gallery Bistro
# 2                    4 Stones Vegetarian Cuisine
# 3                             A La Mode Pie Café
# 4                    A Taste Of India Restaurant
# ..                                           ...
# 892         iDen & Quan Ju De Beijing Duck House
# 893                             sushi California
# 894                                  tetsu Sushi
# 895                                    the apron
# 896                                   the change
#
#                                          Cuisine
# 0                      €26 - €34, Bar,  Canadian
# 1             €14 - €24, Canadian,  Contemporary
# 2                    Chinese,  Asian,  Taiwanese
# 3                        Soups,  Cafe,  Canadian
# 4    Indian, Vegetarian Friendly,  Vegan Options
# ..                                           ...
# 892                   Chinese,  European,  Asian
# 893                     Japanese,  Sushi,  Asian
# 894                     Japanese,  Sushi,  Asian
# 895           €3 - €21, Canadian,  International
# 896                    €7 - €34, Chinese,  Asian
#
# [897 rows x 2 columns]

# %% [markdown]
# ### Merge

# %% [markdown]
# Let's merge restaurant info with reviews and rating.

# %%
# merger 2 tables (review and rating with restaurant info) on restaurant name

df_final = df.merge(df_type, on='restaurant', how='left' )
df_final
# Out:
#                            restaurant  \
# 0      Hydra Estiatorio Mediterranean
# 1      Hydra Estiatorio Mediterranean
# 2      Hydra Estiatorio Mediterranean
# 3      Hydra Estiatorio Mediterranean
# 4      Hydra Estiatorio Mediterranean
# ...                               ...
# 18442         Beach Ave Bar and Grill
# 18443         Beach Ave Bar and Grill
# 18444         Beach Ave Bar and Grill
# 18445         Beach Ave Bar and Grill
# 18446         Beach Ave Bar and Grill
#
#                                                   review  rating  \
# 0      Wonderful fresh exotic Greek food that is deli...     5.0
# 1      Food was delicious, packed full of flavors. Th...     5.0
# 2      Hello, We would like to say thank you for the ...     5.0
# 3      Happy hour was amazing. Buck a shuck oysters a...     5.0
# 4      Roman was the best waiter! he checked up on us...     5.0
# ...                                                  ...     ...
# 18442  Stopped in for lunch while I was walking the S...     5.0
# 18443  Great food and beer in a perfect spot looking ...     5.0
# 18444  We dine here often. And I almost always get a ...     5.0
# 18445  The Beach Ave bar and grill is lovely spot to ...     5.0
# 18446  My wife & I, who live in northern BC, rented a...     5.0
#
#                          Cuisine
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 18442  €10 - €27, Brew Pub,  Pub
# 18443  €10 - €27, Brew Pub,  Pub
# 18444  €10 - €27, Brew Pub,  Pub
# 18445  €10 - €27, Brew Pub,  Pub
# 18446  €10 - €27, Brew Pub,  Pub
#
# [18447 rows x 4 columns]

# %%
df_final.nunique()
# Out:
# restaurant     1009
# review        16606
# rating            4
# Cuisine         532
# dtype: int64

# %%
df_final.to_csv('df_final_table', index=False)

# %% [markdown]
# For further analysis we have 1009 restaurants with rating, reviews and information about them.
